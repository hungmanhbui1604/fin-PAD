# %%
from foreground_extraction import extract_one
from visualization import visualize_foreground_extraction

# %%
IMAGE_PATH = '/home/hmb1604/datasets/LivDet/2011/Sagem/Train/Live/2360691_20100406130854_Enroll_R1_1_FG09_01_Li.bmp'
BLOCK_SIZE = 3
DELTA = 24
KERNEL_SIZE = 13

# %%
original, binarized, dilated, foreground_mask, foreground = extract_one(IMAGE_PATH, BLOCK_SIZE, DELTA, KERNEL_SIZE)

visualize_foreground_extraction(original, binarized, dilated, foreground_mask, foreground)
